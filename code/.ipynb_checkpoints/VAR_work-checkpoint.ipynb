# %%
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
import fuzzy as fy
from collections import namedtuple
from collections import defaultdict
import numpy as np
from statsmodels.tsa.base.datetools import dates_from_str
from statsmodels.tsa.vector_ar.var_model import VAR
# import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels as sm

# %%
nat = pd.read_csv('NationalNames.csv')

# %%
samp = nat.sample(100000)

# %%
soundex = fy.Soundex(4)
samp['Soundex'] = samp.Name.apply(soundex)

# %%
samp['new_name'] = samp.Name.str.lower()

# %%
samp = samp.set_index(['Year'])

# %%
samp['sound_strip'] = samp.Soundex.map(lambda x: x.strip('0'))
samp['first_syl'] = samp.sound_strip.str[0]

# %%
# samp.pivot('first_syl', 'index', 'Count')
df_raw = pd.pivot_table(samp,'Count', samp.index,'first_syl', aggfunc=np.sum)

# %%
df = df_raw.drop(['Q','U','X','Y','Z'], axis=1)

# %%
df_subset = df[(df.index < 1910) & (df.index < 2000)]

# %%
pd.set_option('display.max_columns', 500)

# %%
data = np.log(df_subset).diff(16)

# %%
years = pd.date_range('1950-1-1', periods=40, freq='A-JAN')
data.index = years
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c6bab03441ca> in <module>()
#       1 years = pd.date_range('1950-1-1', periods=40, freq='A-JAN')
# ----> 2 data.index = years
#
# /Users/courtneymorris/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __setattr__(self, name, value)
#    2680         try:
#    2681             object.__getattribute__(self, name)
# -> 2682             return object.__setattr__(self, name, value)
#    2683         except AttributeError:
#    2684             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:45018)()
#
# /Users/courtneymorris/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _set_axis(self, axis, labels)
#     423
#     424     def _set_axis(self, axis, labels):
# --> 425         self._data.set_axis(axis, labels)
#     426         self._clear_item_cache()
#     427
#
# /Users/courtneymorris/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in set_axis(self, axis, new_labels)
#    2576             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2577                              'new values have %d elements' %
# -> 2578                              (old_len, new_len))
#    2579
#    2580         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 30 elements, new values have 40 elements

# %%
data = data.dropna()

# %%
model = VAR(data)

# %%
results = model.fit(2)
results.summary()

# %%
# ols_model = sm.OLS(data, sm.add_constant(data.index)).fit()

# %%
df_raw.head()
# Out:
# first_syl       A       B       C      D       E      F       G       H  \
# Year
# 1880        281.0  1083.0   241.0   61.0  2062.0   55.0    45.0  2823.0
# 1881        353.0    34.0  1655.0   28.0   135.0  109.0     NaN   213.0
# 1882        181.0    58.0  1142.0  188.0   458.0   47.0   174.0    37.0
# 1883        903.0  1395.0   128.0  658.0  2857.0   12.0   111.0    76.0
# 1884       1188.0   426.0    83.0  944.0  1828.0  813.0  1254.0   255.0
#
# first_syl      I      J  ...    Q       R      S       T     U      V      W  \
# Year                     ...
# 1880       169.0  729.0  ...  NaN   343.0   59.0    39.0   NaN   42.0   42.0
# 1881        47.0   82.0  ...  NaN   483.0  258.0  2396.0   NaN    NaN    9.0
# 1882         NaN  121.0  ...  NaN    42.0   33.0    56.0   NaN    5.0   47.0
# 1883       153.0  547.0  ...  NaN    21.0  121.0     NaN  14.0  355.0  127.0
# 1884       109.0  485.0  ...  NaN  1281.0  384.0   250.0   NaN   43.0  652.0
#
# first_syl   X   Y     Z
# Year
# 1880      NaN NaN  10.0
# 1881      NaN NaN   NaN
# 1882      NaN NaN  32.0
# 1883      NaN NaN   6.0
# 1884      NaN NaN  27.0
#
# [5 rows x 26 columns]

# %%
dfsound = df_raw.copy()

# %%
dfsound = dfsound.fillna(0)

# %%
dfsound['sound1'] = dfsound.B + dfsound.F + dfsound.P + dfsound.V

# %%
dfsound = dfsound.drop(['B','F','P','V'], axis=1)

# %%
dfsound['sound2'] = dfsound.C + dfsound.G + dfsound.J + dfsound.K + dfsound.Q + dfsound.S + dfsound.X + dfsound.Z

# %%
dfsound = dfsound.drop(['C','G','J','K','Q','S','X','Z'], axis=1)

# %%
dfsound['sound3'] = dfsound['D'] + dfsound['T']

# %%
dfsound = dfsound.drop(['D','T'], axis=1)

# %%
dfsound['sound4'] = dfsound.L
dfsound = dfsound.drop('L', axis=1)

# %%
dfsound['sound5'] = dfsound.M + dfsound.N
dfsound = dfsound.drop(['M','N'], axis=1)

# %%
dfsound['sound6'] = dfsound.R
dfsound = dfsound.drop('R', axis=1)

# %%
dfsound['soft_sound'] = dfsound.A + dfsound.E + dfsound.H + dfsound.I + dfsound.O + dfsound.U + dfsound.W + dfsound.Y

# %%
dfsound = dfsound.drop(['A','E','H','I','O','U','W','Y'], axis=1)

# %%
dfsound_50 = dfsound[(dfsound.index >= 1882) & (dfsound.index < 2010)]

# %%
years = pd.date_range('1880-1-1', periods=128, freq='A-JAN')

# %%
dfsound_50.index = years

# %%
sound_data = np.log(dfsound_50).diff()

# %%
sound_data = sound_data.dropna()

# %%
sound_data.head()
# Out:
# first_syl              sound1    sound2    sound3    sound4    sound5  \
# 1881-01-31 00:00:00 -0.584745 -0.438066  2.315657  0.088428 -0.720011
# 1882-01-31 00:00:00 -0.063220 -0.166080 -1.273430 -0.814661 -0.052075
# 1883-01-31 00:00:00  0.779196  1.341882  1.817715 -0.317689  1.913735
# 1884-01-31 00:00:00  1.019235 -0.818932 -3.566335  1.527608 -2.608187
# 1885-01-31 00:00:00 -0.702164  0.329431  1.688865 -0.924533  0.965702
#
# first_syl              sound6  soft_sound
# 1881-01-31 00:00:00 -1.979501   -0.763854
# 1882-01-31 00:00:00  2.967064    0.955676
# 1883-01-31 00:00:00 -0.162387   -0.102372
# 1884-01-31 00:00:00  0.317496   -0.946901
# 1885-01-31 00:00:00 -1.809151    2.041954

# %%
sound_model = VAR(sound_data)

# %%
sound_results = sound_model.fit(2)

# %%
sound_results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 22, Jun, 2016
# Time:                     20:12:04
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                   0.542261
# Nobs:                     125.000    HQIC:                 -0.868367
# Log likelihood:          -1021.98    FPE:                   0.161155
# AIC:                     -1.83352    Det(Omega_mle):       0.0728984
# --------------------------------------------------------------------
# Results for equation sound1
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.008950         0.070242            0.127           0.899
# L1.sound1            -0.681362         0.081983           -8.311           0.000
# L1.sound2             0.290580         0.104657            2.777           0.006
# L1.sound3            -0.066992         0.072143           -0.929           0.355
# L1.sound4             0.037979         0.076357            0.497           0.620
# L1.sound5             0.203521         0.073913            2.754           0.007
# L1.sound6             0.157783         0.053586            2.944           0.004
# L1.soft_sound        -0.043305         0.126850           -0.341           0.733
# L2.sound1            -0.362845         0.080685           -4.497           0.000
# L2.sound2             0.393704         0.105199            3.742           0.000
# L2.sound3            -0.007938         0.070760           -0.112           0.911
# L2.sound4             0.091459         0.075544            1.211           0.229
# L2.sound5             0.271266         0.074740            3.629           0.000
# L2.sound6             0.136669         0.053142            2.572           0.011
# L2.soft_sound         0.006504         0.127332            0.051           0.959
# ================================================================================
#
# Results for equation sound2
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.085551         0.062788            1.363           0.176
# L1.sound1            -0.086251         0.073284           -1.177           0.242
# L1.sound2            -0.773459         0.093551           -8.268           0.000
# L1.sound3             0.031486         0.064488            0.488           0.626
# L1.sound4            -0.063518         0.068255           -0.931           0.354
# L1.sound5            -0.085580         0.066069           -1.295           0.198
# L1.sound6             0.027499         0.047900            0.574           0.567
# L1.soft_sound        -0.075206         0.113389           -0.663           0.509
# L2.sound1            -0.014272         0.072123           -0.198           0.844
# L2.sound2            -0.448252         0.094035           -4.767           0.000
# L2.sound3            -0.039681         0.063251           -0.627           0.532
# L2.sound4            -0.087749         0.067528           -1.299           0.197
# L2.sound5            -0.003724         0.066809           -0.056           0.956
# L2.sound6            -0.004074         0.047503           -0.086           0.932
# L2.soft_sound        -0.006591         0.113820           -0.058           0.954
# ================================================================================
#
# Results for equation sound3
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.050044         0.090780            0.551           0.583
# L1.sound1            -0.040361         0.105955           -0.381           0.704
# L1.sound2            -0.044429         0.135257           -0.328           0.743
# L1.sound3            -0.675493         0.093237           -7.245           0.000
# L1.sound4             0.128809         0.098684            1.305           0.195
# L1.sound5            -0.006021         0.095524           -0.063           0.950
# L1.sound6            -0.048594         0.069254           -0.702           0.484
# L1.soft_sound         0.093716         0.163939            0.572           0.569
# L2.sound1            -0.007202         0.104277           -0.069           0.945
# L2.sound2            -0.041573         0.135958           -0.306           0.760
# L2.sound3            -0.265835         0.091449           -2.907           0.004
# L2.sound4            -0.105176         0.097632           -1.077           0.284
# L2.sound5            -0.087081         0.096593           -0.902           0.369
# L2.sound6            -0.056925         0.068680           -0.829           0.409
# L2.soft_sound         0.060990         0.164562            0.371           0.712
# ================================================================================
#
# Results for equation sound4
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.009674         0.082121            0.118           0.906
# L1.sound1            -0.005719         0.095848           -0.060           0.953
# L1.sound2             0.260295         0.122355            2.127           0.036
# L1.sound3             0.054034         0.084343            0.641           0.523
# L1.sound4            -0.564527         0.089270           -6.324           0.000
# L1.sound5             0.165752         0.086412            1.918           0.058
# L1.sound6             0.071876         0.062648            1.147           0.254
# L1.soft_sound        -0.182954         0.148301           -1.234           0.220
# L2.sound1             0.131447         0.094330            1.393           0.166
# L2.sound2             0.076959         0.122989            0.626           0.533
# L2.sound3            -0.033740         0.082726           -0.408           0.684
# L2.sound4            -0.392307         0.088319           -4.442           0.000
# L2.sound5             0.069346         0.087379            0.794           0.429
# L2.sound6             0.022611         0.062129            0.364           0.717
# L2.soft_sound        -0.002399         0.148865           -0.016           0.987
# ================================================================================
#
# Results for equation sound5
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.030378         0.085183            0.357           0.722
# L1.sound1             0.020963         0.099422            0.211           0.833
# L1.sound2             0.095992         0.126918            0.756           0.451
# L1.sound3            -0.135429         0.087489           -1.548           0.125
# L1.sound4            -0.080059         0.092600           -0.865           0.389
# L1.sound5            -0.652839         0.089635           -7.283           0.000
# L1.sound6             0.029875         0.064984            0.460           0.647
# L1.soft_sound         0.216217         0.153832            1.406           0.163
# L2.sound1             0.016829         0.097848            0.172           0.864
# L2.sound2             0.316882         0.127576            2.484           0.015
# L2.sound3            -0.132856         0.085811           -1.548           0.124
# L2.sound4            -0.063327         0.091613           -0.691           0.491
# L2.sound5            -0.238897         0.090638           -2.636           0.010
# L2.sound6             0.106791         0.064446            1.657           0.100
# L2.soft_sound         0.189304         0.154417            1.226           0.223
# ================================================================================
#
# Results for equation sound6
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.029402         0.108985            0.270           0.788
# L1.sound1             0.007585         0.127203            0.060           0.953
# L1.sound2             0.347802         0.162382            2.142           0.034
# L1.sound3             0.172097         0.111935            1.537           0.127
# L1.sound4            -0.024612         0.118474           -0.208           0.836
# L1.sound5            -0.011450         0.114680           -0.100           0.921
# L1.sound6            -0.601905         0.083142           -7.239           0.000
# L1.soft_sound        -0.056250         0.196816           -0.286           0.776
# L2.sound1            -0.086349         0.125189           -0.690           0.492
# L2.sound2             0.031467         0.163223            0.193           0.847
# L2.sound3             0.307873         0.109788            2.804           0.006
# L2.sound4             0.155137         0.117211            1.324           0.188
# L2.sound5            -0.217258         0.115964           -1.873           0.064
# L2.sound6            -0.442315         0.082453           -5.364           0.000
# L2.soft_sound         0.116785         0.197564            0.591           0.556
# ================================================================================
#
# Results for equation soft_sound
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.037654         0.049882            0.755           0.452
# L1.sound1             0.072877         0.058220            1.252           0.213
# L1.sound2            -0.011900         0.074322           -0.160           0.873
# L1.sound3             0.018838         0.051232            0.368           0.714
# L1.sound4             0.038599         0.054225            0.712           0.478
# L1.sound5             0.017008         0.052489            0.324           0.747
# L1.sound6            -0.013815         0.038054           -0.363           0.717
# L1.soft_sound        -0.658463         0.090082           -7.310           0.000
# L2.sound1             0.027392         0.057299            0.478           0.634
# L2.sound2             0.052878         0.074707            0.708           0.481
# L2.sound3             0.035882         0.050250            0.714           0.477
# L2.sound4             0.032517         0.053647            0.606           0.546
# L2.sound5            -0.001903         0.053076           -0.036           0.971
# L2.sound6            -0.057245         0.037739           -1.517           0.132
# L2.soft_sound        -0.257749         0.090425           -2.850           0.005
# ================================================================================
#
# Correlation matrix of residuals
#                 sound1    sound2    sound3    sound4    sound5    sound6  soft_sound
# sound1        1.000000  0.182332  0.104833  0.025859 -0.096974  0.110605   -0.095243
# sound2        0.182332  1.000000  0.133862 -0.232231 -0.148950 -0.201251    0.003741
# sound3        0.104833  0.133862  1.000000  0.039484  0.054447 -0.057983    0.050894
# sound4        0.025859 -0.232231  0.039484  1.000000  0.053511  0.052838    0.014789
# sound5       -0.096974 -0.148950  0.054447  0.053511  1.000000 -0.053600    0.062342
# sound6        0.110605 -0.201251 -0.057983  0.052838 -0.053600  1.000000   -0.019839
# soft_sound   -0.095243  0.003741  0.050894  0.014789  0.062342 -0.019839    1.000000

# %%
# sound_results.plot_acorr()

# %%
#Sound 1 figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.sound1, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.sound1, lags=30, ax=ax2)

# %%
#Sound 2 figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.sound2, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.sound2, lags=30, ax=ax2)

# %%
#Sound 3 figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.sound3, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.sound3, lags=30, ax=ax2)

# %%
#Sound 4 figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.sound4, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.sound4, lags=30, ax=ax2)

# %%
#Sound 5 figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.sound5, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.sound5, lags=30, ax=ax2)

# %%
#Soft Sound figures

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sound_data.soft_sound, lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sound_data.soft_sound, lags=30, ax=ax2)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

def plot_acf_pacf(your_data, lags):
   fig = plt.figure(figsize=(12,8))
   ax1 = fig.add_subplot(211)
   fig = plot_acf(your_data, lags=lags, ax=ax1)
   ax2 = fig.add_subplot(212)
   fig = plot_pacf(your_data, lags=lags, ax=ax2)
   plt.show()

# %%
plot_acf_pacf(sound_data.sound1, 30)

# %%
soft_model = SARIMAX(sound_data.soft_sound, order=(1,1,1)).fit()

# %%
soft_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:             soft_sound   No. Observations:                  127
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -109.304
# Date:                Wed, 22 Jun 2016   AIC                            224.609
# Time:                        20:22:24   BIC                            233.142
# Sample:                    01-31-1881   HQIC                           228.076
#                          - 01-31-2007
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5329      0.075     -7.095      0.000      -0.680      -0.386
# ma.L1         -0.9998      5.683     -0.176      0.860     -12.138      10.138
# sigma2         0.3165      1.808      0.175      0.861      -3.227       3.860
# ===================================================================================
# Ljung-Box (Q):                       73.12   Jarque-Bera (JB):                 7.77
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               1.41   Skew:                             0.46
# Prob(H) (two-sided):                  0.27   Kurtosis:                         3.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from scipy.optimize import brute

exog = sound_data.soft_sound
endog = sound_data.index

def objfunc(order, exog, endog):
    fit = SARIMAX(endog, order, exog).fit()
    return fit.aic()

grid = (slice(1, 3, 1), slice(1, 3, 1), slice(1, 3, 1))

# %%
brute(sm.tsa.statespace.sarimax.SARIMAX, (slice(1, 3, 1), slice(1, 3, 1), slice(1, 3, 1)), finish=None)
# Out:
# array([ 1.,  1.,  2.])

# %%
sound_data.soft_sound.ewm(halflife=8)
# Out:
# EWM [com=11.048779707,min_periods=0,adjust=True,ignore_na=False,axis=0]

# %%
def plot_sounds(series):
    fig = plt.figure(figsize=(8,6))
    plt.plot(series)

# %%
plot_sounds(sound_data.sound1),
plot_sounds(sound_data.sound2),
plot_sounds(sound_data.sound3)
